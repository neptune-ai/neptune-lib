# %% [markdown]
# # Get neptune experiment view (leaderboard)
# ## Instantiate a session
# In order to fetch data from Neptune you need to get your `api_token` first.
# To get it run:
#
# ```bash
# neptune account api-token get
# ```
#
# Now you can either pass it directly to a `Session` object or
# you can put it in the `NEPTUNE_API_TOKEN` environment variable.
#
# ```bash
# export NEPTUNE_API_TOKEN=YOUR_API_TOKEN
# ```
#
# Either way you can start a session now.

# %%
from neptunelib.session import Session
# session=Session(api_token=YOUR_API_TOKEN)
session = Session()

# %% [markdown]
# ## Fetch project
# You need to choose the project on which you want to work on.
# Let's take the `neptune-ml/Salt-Detecion` project from the `neptune-ml` organization.
#
# Use `.get_projects(ORGANIZATION)[ORGANIZATION/PROJECT_NAME]` method which takes organization as input and outputs a dictionary.

# %%
project = session.get_projects('neptune-ml')['neptune-ml/Salt-Detection']

# %% [markdown]
# ## Fetch experiment view
# Now you can fetch the entire, or filtered experiment view to your local machine.
# Use `.get_leaderboard(*kwargs)` to do so.
# For example lets fetch 4 experiments by specifying their state.
#
# **Note**
#
# There are other options to select experiments such as `tags` or `id`. You can read about them in the user guide.

# %%
leaderboard = project.get_leaderboard(state=['succeeded','aborted'])
leaderboard.head()
# Out:
#         id                               name  \
# 0  SAL-204  tgs_salt_identification_challenge
# 1  SAL-239  tgs_salt_identification_challenge
# 2  SAL-240                                  1
# 3  SAL-241                                  2
# 4  SAL-242                                  3
#
#                            created                         finished   owner  \
# 0 2018-07-25 09:43:00.645000+00:00 2018-07-25 12:19:44.634000+00:00  czakon
# 1 2018-07-25 11:38:19.497000+00:00 2018-07-25 11:38:40.276000+00:00  czakon
# 2 2018-07-25 11:39:07.916000+00:00 2018-07-25 11:41:21.879000+00:00  czakon
# 3 2018-07-25 11:39:07.916000+00:00 2018-07-25 11:40:25.338000+00:00  czakon
# 4 2018-07-25 11:39:07.916000+00:00 2018-07-25 11:40:07.287000+00:00  czakon
#
#   worker_type environment                                  git_hash notes  \
# 0        None        None  b4555937806efc73344fcc3f5d46ed4aec3a9f1d
# 1        None        None  304f9628a7b57a46fc01b653b5c18665c958d675
# 2        None        None  304f9628a7b57a46fc01b653b5c18665c958d675
# 3        None        None  304f9628a7b57a46fc01b653b5c18665c958d675
# 4        None        None  304f9628a7b57a46fc01b653b5c18665c958d675
#
#    running_time          ...            \
# 0          9402          ...
# 1            19          ...
# 2            17          ...
# 3            17          ...
# 4            17          ...
#
#                            parameter_test_images_dir  \
# 0  /mnt/ml-team/minerva/open-solutions/salt/files...
# 1  /mnt/ml-team/minerva/open-solutions/salt/files...
# 2  /mnt/ml-team/minerva/open-solutions/salt/files...
# 3  /mnt/ml-team/minerva/open-solutions/salt/files...
# 4  /mnt/ml-team/minerva/open-solutions/salt/files...
#
#    parameter_threshold_masks  \
# 0                        0.2
# 1                        0.5
# 2                        0.2
# 3                        0.3
# 4                        0.4
#
#                           parameter_train_images_dir  \
# 0  /mnt/ml-team/minerva/open-solutions/salt/files...
# 1  /mnt/ml-team/minerva/open-solutions/salt/files...
# 2  /mnt/ml-team/minerva/open-solutions/salt/files...
# 3  /mnt/ml-team/minerva/open-solutions/salt/files...
# 4  /mnt/ml-team/minerva/open-solutions/salt/files...
#
#   parameter_tta_aggregation_method parameter_unet_activation  \
# 0                            gmean                   sigmoid
# 1                            gmean                   sigmoid
# 2                            gmean                   sigmoid
# 3                            gmean                   sigmoid
# 4                            gmean                   sigmoid
#
#   parameter_unet_output_channels parameter_use_batch_norm parameter_use_depth  \
# 0                            2.0                      1.0                 NaN
# 1                            2.0                      1.0                 NaN
# 2                            2.0                      1.0                 NaN
# 3                            2.0                      1.0                 NaN
# 4                            2.0                      1.0                 NaN
#
#   parameter_validation_metric_name parameter_weight_decay
# 0                             iout                    NaN
# 1                             iout                    NaN
# 2                             iout                    NaN
# 3                             iout                    NaN
# 4                             iout                    NaN
#
# [5 rows x 214 columns]
